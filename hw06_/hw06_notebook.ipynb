# %% [markdown]
# Логистическая регрессия (теория):

# %% [markdown]
# Внезапно оказалось, что домашнего задания после 6-го занятия не было, посему использую этот файл для благодарности нашим прекрасным лекторам за то, что разжевали нам, как работает логистическая регрессия (ну или пытались разжевать хехе) и на что стоит обратить внимание. Было познавательно. Спасибо!
