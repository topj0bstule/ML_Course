# %% [markdown]
# Линейная регрессия

# %% [markdown]
# Внезапно оказалось, что домашнего задания после 5-го занятия не было, посему использую этот файл для благодарности Ивану - прекрасному лектору и просто хорошему человеку за то, что разжевал подробно: как работает линейная регрессия, на что стоит обратить внимание, а также за то, что предоставил на практическом занятии пример своего EDA + feature engineering-а + обучения моделей линейной регрессии на датасете ToyotaCorolla. Было очень познавательно и крайне полезно (особенно последняя часть ноутубка с практического занятия, где показывалось применение статистики Колмогорова-Смирнова и P-значения). Спасибо большое!
